# %% [markdown]
# #Variable name:
# 1. Variable names cannot start with numbers
# 2. Python keywords (reserved words) (e.g., if, while, etc.) cannot be used as variable names.

# %%
x = 2 # number (integer)
y = "Kevin" # text
z = 3.14 # number (float; decimal)

# %%
print(x)
print(y)
print(z)
# Out:
# 2
# Kevin
# 3.14

# %% [markdown]
# # Math Operators

# %%
a = 10
b = 3

# %%
print("a+b", a+b)
print("a-b", a-b)
print("a*b", a*b)
print("a/b", a/b)
print("a%b", a%b)
print("a//b", a//b) #floor division operator -> It divides and then rounds down to the nearest integer.
print("a**b", a ** b)
# Out:
# a+b 13
# a-b 7
# a*b 30
# a/b 3.3333333333333335
# a%b 1
# a//b 3
# a**b 1000

# %% [markdown]
# # Comparison Operator (used in boolean expression)
#
#
# *   Boolean --> True or False
# *   Boolean expression --> evaluated to be either True or False.

# %%
a = 5
b = 8

# %%
print(" a == b", a == b) # a is equal to b?
print(" a != b", a != b) # a is not equal to b?
print(" a < b", a < b) # a is less than b?
print(" a > b ", a > b) # a is greater than b?
print(" a <= b", a <= b ) # a is less than or equal to b?
print("a >= b", a >= b) # a is greater than or equal to b?
# Out:
#  a == b False
#  a != b True
#  a < b True
#  a > b  False
#  a <= b True
# a >= b False

# %%
#quiz problem
x = 12
y = 4

(x -y) * y / x
# Out:
# 2.6666666666666665

# %% [markdown]
# # Boolean operator
# *   and
# *   or
# *   not

# %%
# and operator
a = True
b = False

# %%
#and operator
print("a and b", a and b) # False For "a and b" to be true, both a and b must be true
# Out:
# False

# %%
# or opertor
print("a or b", a or b) #True For "a or b" to be true, only one of them can be True
# Out:
# a or b True

# %%
# not operator
print("not a", not a)
# Out:
# not a False
